# %%
# @title Setup Environment.
from pathlib import Path
import os

lang, branch = 'en', 'main'
scripts_dir = Path.home() / 'ANXETY' / 'scripts'
out = scripts_dir / 'setup.py'

os.makedirs(out.parent, exist_ok=True)
# !curl -sLo {out} https://raw.githubusercontent.com/anxety-solo/sdAIgen/{branch}/scripts/setup.py

# %run $out --lang=$lang --branch=$branch
# Out:
#     <div class="season-container">
#       <div class="text-container">
#         <span>🌴</span>
#         <span>A</span><span>N</span><span>X</span><span>E</span><span>T</span><span>Y</span>
#         <span>&nbsp;</span>
#         <span>S</span><span>D</span><span>-</span><span>W</span><span>E</span><span>B</span><span>U</span><span>I</span>
#         <span>&nbsp;</span>
#         <span>V</span><span>2</span>
#         <span>🌴</span>
#       </div>
#
#       <div class="message-container">
#         <span>Done! Now you can run the cells below. ☄️</span>
#         <span>Runtime environment: <span class="env">Google Colab</span></span>
#         <span>File location: <span class="files-location">/root/ANXETY</span></span>
#
#         <span>Current branch: <span class="branch">main</span></span>
#       </div>
#     </div>
#
#     <style>
#     @import url('https://fonts.googleapis.com/css2?family=Righteous&display=swap');
#
#     .season-container {
#       position: relative;
#       margin: 0 10px !important;
#       padding: 20px !important;
#       border-radius: 15px;
#       margin: 10px 0;
#       overflow: hidden;
#       min-height: 200px;
#       background: linear-gradient(180deg, #ffe76633, transparent);
#       border-top: 2px solid #ffe766;
#       animation: fadeIn 0.5s ease-in !important;
#     }
#
#     @keyframes fadeIn {
#       from { opacity: 0; }
#       to { opacity: 1; }
#     }
#
#     .text-container {
#       display: flex;
#       flex-wrap: wrap;
#       justify-content: center;
#       align-items: center;
#       gap: 0.5em;
#       font-family: 'Righteous', cursive;
#       margin-bottom: 1em;
#     }
#
#     .text-container span {
#       font-size: 2.5rem;
#       color: #ffe766;
#       opacity: 0;
#       transform: translateY(-20px);
#       filter: blur(4px);
#       transition: all 0.5s cubic-bezier(0.175, 0.885, 0.32, 1.275);
#     }
#
#     .text-container.loaded span {
#       opacity: 1;
#       transform: translateY(0);
#       filter: blur(0);
#       color: #fff7cc;
#     }
#
#     .message-container {
#       font-family: 'Righteous', cursive;
#       text-align: center;
#       display: flex;
#       flex-direction: column;
#       gap: 0.5em;
#     }
#
#     .message-container span {
#       font-size: 1.2rem;
#       color: #ffe766;
#       opacity: 0;
#       transform: translateY(20px);
#       transition: all 0.5s cubic-bezier(0.175, 0.885, 0.32, 1.275);
#     }
#
#     .message-container.loaded span {
#       opacity: 1;
#       transform: translateY(0);
#       color: #fff7cc;
#     }
#
#     .env { color: #FFA500 !important; }
#     .files-location { color: #FF99C2 !important; }
#     .branch { color: #16A543 !important; }
#     .fork { color: #C786D3 !important; }
#     </style>
#
#     <script>
#     (function() {
#       // Text animation
#       const textContainer = document.querySelector('.text-container');
#       const messageContainer = document.querySelector('.message-container');
#       const textSpans = textContainer.querySelectorAll('span');
#       const messageSpans = messageContainer.querySelectorAll('span');
#
#       textSpans.forEach((span, index) => {
#         span.style.transitionDelay = `${index * 25}ms`;
#       });
#
#       messageSpans.forEach((span, index) => {
#         span.style.transitionDelay = `${index * 50}ms`;
#       });
#
#       setTimeout(() => {
#         textContainer.classList.add('loaded');
#         messageContainer.classList.add('loaded');
#       }, 250);
#     })();
#     </script>
#     <script>
#     (function() {
#       const container = document.querySelector('.season-container');
#       const style = document.createElement('style');
#       style.innerHTML = `
#         .stick-particle {
#           position: absolute;
#           width: 2px;
#           height: 15px;
#           background: #ffd700;
#           transform-origin: center bottom;
#           opacity: 0;
#           pointer-events: none;
#         }
#         @keyframes stick-fall {
#           0% { opacity: 0; transform: translate(-50%, -50%) rotate(0) scale(0.5); }
#           20% { opacity: 0.8; transform: translate(-50%, -50%) rotate(0deg) scale(1); }
#           100% { opacity: 0; transform: translate(-50%, 150%) rotate(180deg) scale(0.5); }
#         }
#       `;
#       document.head.appendChild(style);
#
#       let activeParticles = 0;
#       const maxParticles = 25;
#
#       function createStick() {
#         if (activeParticles >= maxParticles) return;
#
#         const stick = document.createElement('div');
#         stick.className = 'stick-particle';
#         const startX = Math.random() * 100;
#         const duration = Math.random() * 4 + 3;
#         const rotation = (Math.random() - 0.5) * 180;
#
#         stick.style.cssText = `
#           left: ${startX}%;
#           top: ${Math.random() * 100}%;
#           animation: stick-fall ${duration}s linear forwards;
#           transform: rotate(${rotation}deg);
#         `;
#
#         activeParticles++;
#         stick.addEventListener('animationend', () => {
#           stick.remove();
#           activeParticles--;
#         });
#
#         container.appendChild(stick);
#       }
#
#       const interval = setInterval(createStick, 100);
#
#       // Cleanup when container is removed
#       const observer = new MutationObserver(() => {
#         if (!document.contains(container)) {
#           clearInterval(interval);
#           observer.disconnect();
#         }
#       });
#       observer.observe(document.body, { childList: true, subtree: true });
#     })();
#     </script>

# %% [markdown]
# ---
# ## 1. Widgets 🔽

# %%
# Model selection, vae, control-net and more.
# %run $scripts_dir/$lang/widgets-{lang}.py
# Out:
# <style>@import url('https://fonts.googleapis.com/css2?family=Shantell+Sans:ital,wght@0,300..800;1,300..800&family=Tiny5&display=swap');
#
# :root {
#     /* Accent Color */
#     --aw-accent-color: #ff97ef;
#     --aw-elements-shadow: 0 0 15px rgba(0, 0, 0, 0.35);
#
#     /* Text - Fonts */
#     --aw-font-family-primary: "Shantell Sans", serif;
#     --aw-font-family-secondary: "Tiny5", sans-serif;
#     --aw-color-text-primary: #f0f8ff;
#     --aw-text-size: 14px;
#     --aw-text-size-small: 13px;
#
#     /* Container */
#     --aw-container-bg: #232323;
#     --aw-container-border: 2px solid rgba(0, 0, 0, 0.4);
#     --aw-conteiner-gap: 5px;
#
#     /* Inputs */
#     --aw-input-bg: #1c1c1c;
#     --aw-input-bg-hover: #262626;
#     --aw-input-border: 1px solid #262626;
#     --aw-input-border-focus: #006ee5;
#
#     /* Checkboxes */
#     --aw-checkbox-unchecked-bg: #20b2aa;
#     --aw-checkbox-checked-bg: #2196f3;
#     --aw-checkbox-inpaint-bg: #bbca53;
#     --aw-checkbox-sdxl-bg: #ea861a;
#     --aw-checkbox-empowerment-bg: #df6b91;
#     --aw-checkbox-handle-bg: white;
#
#     /* Popup */
#     --aw-popup-blur: 10px;
#     --aw-popup-bg: rgba(255, 255, 255, 0.03);
#     --aw-popup-color: #ffffff;
#     --aw-popup-border: 2px solid rgba(255, 255, 255, 0.45);
#     --aw-popup-sample-bg: rgba(255, 255, 255, 0.1);
#     --aw-popup-sample-color: #c6e2ff;
#     --aw-popup-sample-border: 2px solid rgba(255, 255, 255, 0.2);
#
#     /* Term Colors (Popup) */
#     --aw-term-sample-label: #dbafff;
#     --aw-term-braces: #ffff00;
#     --aw-term-extension: #eb934b;
#     --aw-term-filename: #ffdba7;
#     --aw-term-required: #ff9999;
#
#     /* Scrollbar */
#     --aw-scrollbar-width: 0.65rem;
#     --aw-scrollbar-thumb-bg: #475254;
#     --aw-scrollbar-track-bg: #111111;
#     --aw-scrollbar-thumb-hover: var(--aw-accent-color);
#
#     /* Buttons */
#     --aw-button-gradient: radial-gradient(circle at top left, purple 10%, violet 90%);
#     --aw-button-input-gradient: radial-gradient(circle at top left, var(--aw-input-bg));
#     --aw-button-save-hover: radial-gradient(circle at top left, purple 10%, #93ac47 90%);
#     --aw-button-api-hover: radial-gradient(circle at top left, purple 10%, #1d94bb 90%);
# }
#
#
# /* General Styles */
#
# .header {
#     display: inline-block;
#     font-size: 20px;
#     font-weight: 650;
#     color: var(--aw-accent-color);
#     margin-bottom: 10px;
#     user-select: none;
#     cursor: default;
#     text-shadow: 0 0 10px rgba(255, 255, 255, 0.2);
# }
#
# hr {
#     margin: 4px 0;
#     background-color: grey;
#     border-color: grey;
#     opacity: 0.25;
# }
# a {
#     color: inherit;
#     text-decoration: none;
# }
#
#
# /* == Special fixes for IpyWidgets == */
# /* Remove Shit-Spacing for HTML-Widgets (button) */
# .widget-html:has(.button),
# .widget-html-content:has(.button) {
#     padding: 0;
#     margin: 0;
# }
#
# /* Remove Shit-margin for Boxes */
# .widget-inline-hbox { margin: 2px 0; } /* 2px - default ipywidgets margin */
#
# /* Fix Vertical Centering */
# .widget-hbox,
# .jupyter-widgets label {
#     display: flex;
#     align-items: center;
# }
#
# /* Fix Checkbox Width */
# .widget-checkbox {
#     width: auto;
#     display: inline-flex;
#     min-width: unset;
# }
#
#
# /* Special Styles */
#
# ::selection {
#     background: #3d4142;
# }
# ::-moz-selection { /* Code for Firefox */
#     background: #3d4142;
# }
#
# /* === ScrollBar (For TextArea) === */
# .widget-textarea textarea::-webkit-scrollbar {
#     width: var(--aw-scrollbar-width);
#     height: var(--aw-scrollbar-width);
# }
# .widget-textarea textarea::-webkit-scrollbar-thumb {
#     background: var(--aw-scrollbar-thumb-bg) !important;
#     border: 3px solid var(--aw-scrollbar-track-bg);
#     border-radius: 16px;
# }
# .widget-textarea textarea::-webkit-scrollbar-thumb:hover {
#     background: var(--aw-scrollbar-thumb-hover) !important;
# }
# .widget-textarea textarea::-webkit-scrollbar-track,
# .widget-textarea textarea::-webkit-scrollbar-corner {
#     background: var(--aw-scrollbar-track-bg) !important;
#     border-radius: 0 8px 8px 0;
# }
# /* FireFox Styles */
# @-moz-document url-prefix() {
#     .widget-textarea textarea {
#         scrollbar-width: auto;
#         scrollbar-color: var(--aw-scrollbar-thumb-bg) var(--aw-scrollbar-track-bg);
#     }
# }
#
#
# /* Text FONTs */
#
# .info,
# .popup,
# .button,
# .header,
# .widget-button,
# .widget-text label,
# .widget-checkbox label,
# .widget-dropdown label,
# .widget-dropdown select,
# .widget-textarea textarea,
# .widget-text input[type="text"] {
#     font-family: var(--aw-font-family-primary);
#     font-optical-sizing: auto;
#     /* text-shadow: 1px 1px 2px rgba(0, 0, 0, 0.8); */
# }
#
#
# /* Element Text Style */
#
# .widget-text,
# .widget-button,
# .widget-text label,
# .widget-checkbox label,
# .widget-dropdown label,
# .widget-dropdown select,
# .widget-textarea textarea,
# .widget-text input[type="text"] {
#     font-style: normal;
#     font-size: var(--aw-text-size);
#     color: var(--aw-color-text-primary) !important;
#     user-select: none;
# }
# .widget-text input[type="text"]::placeholder {
#     color: grey;
#     font-size: var(--aw-text-size);
# }
#
# /* TextArea */
# .widget-textarea textarea,
# .widget-textarea textarea::placeholder {
#     font-size: var(--aw-text-size-small);
# }
#
#
# /* Containers Style */
#
# .mainContainer * { overflow: visible !important; } /* Fix For Containers Shadow */
# .mainContainer {
#     padding: calc(var(--aw-conteiner-gap) + 5px);
#     gap: calc(var(--aw-conteiner-gap) + 5px);
# }
# .widgetContainer,
# .sideContainer {
#     gap: var(--aw-conteiner-gap);
# }
# .widgetContainer > .model-vae {
#     gap: var(--aw-conteiner-gap);
#     align-items: stretch;
# }
#
# .container {
#     flex: 1;
#     position: relative;
#     padding: 10px 15px;
#     background-color: var(--aw-container-bg);
#     border: var(--aw-container-border);
#     border-radius: 16px;
#     box-shadow: var(--aw-elements-shadow), inset 0 0 10px rgba(0, 0, 0, 0.3);
#     overflow: hidden !important;
# }
# .container::after {
#     content: "ANXETY";
#     position: absolute;
#     top: 10px;
#     right: 15px;
#     color: rgba(0, 0, 0, 0.3);
#     font-family: var(--aw-font-family-secondary);
#     font-optical-sizing: auto;
#     font-weight: 750;
#     font-size: 24px;
# }
#
# .container_cdl {
#     flex: none;
#     height: 55px;
#     transition: all 0.5s cubic-bezier(0.785, 0.135, 0.15, 0.85);
# }
# .container_cdl.expanded {
#     height: 305px;
# }
#
# /* === SideContainer Buttons === */
# .sideContainer-btn {
#     align-self: flex-start;
#     margin: 0 !important;
#     padding: 0 !important;
#     background-size: 65%;
#     background-position: center;
#     background-repeat: no-repeat;
#     background-color: var(--aw-container-bg);
#     border: var(--aw-container-border);
#     border-radius: 8px;
#     box-shadow: var(--aw-elements-shadow), inset 0 0 10px rgba(0, 0, 0, 0.3) !important;
#     cursor: pointer;
#     outline: none;
#     transition: all 0.15s ease;
# }
# .sideContainer-btn:active {
#     background-color: var(--aw-container-bg);
#     transform: scale(0.95) !important;
# }
#
# /* GDrive Button */
# .gdrive-btn {
#     background-image: url('https://upload.wikimedia.org/wikipedia/commons/1/12/Google_Drive_icon_%282020%29.svg');
# }
# .gdrive-btn.active {
#     background-color: #006d33;
#     border-color: #00d062;
#     /* transform: scale(0.9) !important; */
# }
#
# /* Export/Import Button */
# /* (↓ arrow) --> SVG Icon Page: https://www.svgrepo.com/svg/357903/import */
# .export-btn {
#   background-image: url(data:image/svg+xml;base64,...);
# }
# /* (↑ arrow) --> SVG Icon Page: https://www.svgrepo.com/svg/357723/export */
# .import-btn {
#   background-image: url(data:image/svg+xml;base64,...);
# }
#
# /* Notification PopUp */
# .notification-popup {
#     margin: 0;
#     cursor: default;
#     user-select: none;
#     pointer-events: none;
#     transition: all 0.25s cubic-bezier(0.4, 0, 0.2, 1);
# }
# .notification-popup.hidden {
#     margin-top: 0;
#     opacity: 0;
#     overflow: hidden;
#     transform: translateY(15px) scale(0.9);
# }
# .notification-popup.visible {
#     margin-top: 10px;
#     opacity: 1;
#     overflow: hidden;
#     transform: translateY(0) scale(1);
# }
#
# .notification {
#     position: relative;
#     display: flex;
#     align-items: center;
#     font-family: var(--aw-font-family-primary);
#     font-size: var(--aw-text-size);
#     color:
# <script>// Toggle container visibility and extension (Custom Downloads)
# function toggleContainer() {
#     const SHOW_CLASS = 'showed';
#     const elements = {
#         downloadContainer: document.querySelector('.container_cdl'),
#         info: document.querySelector('.info'),
#         empowerment: document.querySelector('.empowerment')
#     };
#
#     elements.downloadContainer.classList.toggle('expanded');
#     elements.info.classList.toggle(SHOW_CLASS);
#     elements.empowerment.classList.toggle(SHOW_CLASS);
# }
#
# // Trigger file download of JSON content
# function downloadJson(data, filename='widget_settings.json') {
#     const blob = new Blob([JSON.stringify(data, null, 2)], { type: 'application/json' });
#     const url = URL.createObjectURL(blob);
#     const a = document.createElement('a');
#     a.href = url;
#     a.download = filename;
#     a.click();
#     setTimeout(() => URL.revokeObjectURL(url), 1000);
# }
#
# // Open file picker and send parsed JSON to Python callback
# function openFilePicker(callbackName='importSettingsFromJS') {
#     const input = document.createElement('input');
#     input.type = 'file';
#     input.accept = '.json';
#     input.style.display = 'none';
#
#     input.onchange = async (event) => {
#         const file = event.target.files[0];
#         if (!file) return;
#
#         try {
#             const text = await file.text();
#             const jsonData = JSON.parse(text);
#             google.colab.kernel.invokeFunction(callbackName, [jsonData], {});
#         } catch (err) {
#             // Notify Python of JSON parsing error using a registered callback
#             google.colab.kernel.invokeFunction('showNotificationFromJS',
#                 ["Failed to parse JSON: " + err.message, "error"], {});
#         }
#     };
#
#     document.body.appendChild(input);
#     input.click();
#     document.body.removeChild(input);
# }
#
# // Hide Notification PopUp
# function hideNotification(delay = 2500) {
#     setTimeout(() => {
#         const popup = document.querySelector('.notification-popup');
#         if (popup) {
#             setTimeout(() => {
#                 popup.classList.add('hidden')
#                 popup.classList.remove('visible')
#             }, 500);
#         };
#     }, delay);
# }</script>
# HBox(children=(VBox(children=(HBox(children=(VBox(children=(HTML(value='<div class="header">Model Selection</d…

# %% [markdown]
# ## 2. Downloading 🔽

# %%
# Downloading libraries, repos, models and more.
# %run $scripts_dir/$lang/downloading-{lang}.py
# Out:
# 🚀 Unpacking A1111 complete! 00:23 ⚡
# ✨ Update WebUI and Extensions Completed!
# 🏁 Download Complete!
# <style>@import url('https://fonts.googleapis.com/css2?family=Shantell+Sans:ital,wght@0,300..800;1,300..800&family=Tiny5&display=swap');
#
# :root {
#     /* Accent Color */
#     --aw-accent-color: #ac8fa5;
#     --aw-elements-shadow: 0 0 15px rgba(0, 0, 0, 0.35);
#
#     /* Text - Fonts */
#     --aw-font-family-primary: "Shantell Sans", serif;
#     --aw-font-family-secondary: "Tiny5", sans-serif;
#     --aw-color-text-primary: #f0f8ff;
#     --aw-text-size: 14px;
#
#     /* Container */
#     --aw-container-bg: #232323;
#     --aw-container-border: 2px solid rgba(0, 0, 0, 0.4);
#     --aw-output-container-bg: #1f1f1f;
#     --aw-output-section-bg: #181818;
#     --aw-output-section-border: 2px solid rgba(0, 0, 0, 0.35);
#     --aw-output-section-gap: 16px;
# }
#
#
# /* Text FONTs */
#
# .widget-html,
# .header-main-title,
# .section-title {
#     font-family: var(--aw-font-family-primary);
#     font-optical-sizing: auto;
# }
#
#
# /* Element Text Style */
#
# .widget-html {
#     font-size: var(--aw-text-size);
#     color: var(--aw-color-text-primary) !important;
#     user-select: none;
# }
#
#
# /* General Styles */
#
# .header-main-title,
# .section-title {
#     font-size: 20px;
#     font-weight: bold;
#     text-align: center;
# }
# .header-main-title {
#     color: var(--aw-accent-color);
#     text-align: center;
#     margin-bottom: 15px;
# }
# .section-title {
#     color: #0083c0;
# }
#
# hr {
#     background-color: grey;
#     border-color: grey;
#     opacity: 0.25;
# }
#
#
# /* Container Style */
#
# .mainResult-container {
#     position: relative;
#     /* flex-direction: column; */
#     margin: 40px 10px 10px 10px;
#     padding: 15px 30px;
#     background-color: var(--aw-container-bg);
#     border: var(--aw-container-border);
#     border-radius: 16px;
#     box-shadow: var(--aw-elements-shadow), inset 0 0 10px rgba(0, 0, 0, 0.3);
#     text-align: center;
#     overflow: hidden !important;
# }
# .mainResult-container::after {
#     content: "ANXETY";
#     position: absolute;
#     top: 10px;
#     right: 15px;
#     color: rgba(0, 0, 0, 0.3);
#     font-family: var(--aw-font-family-secondary);
#     font-optical-sizing: auto;
#     font-weight: 750;
#     font-size: 24px;
# }
#
# .sectionsContainer {
#     flex-wrap: wrap;
#     padding: 25px;
#     background-color: var(--aw-output-container-bg);
#     border-radius: 8px;
#     box-shadow: inset 0 0 10px rgba(0, 0, 0, 0.3);
#     gap: var(--aw-output-section-gap);
#     align-content: flex-start;
#     align-items: stretch !important;
#     text-align: start;
#     overflow: visible;
# }
# .output-section {
#     flex: 1 1 auto !important;
#     padding: 15px;
#     /* min-width: min-content; */
#     background-color: var(--aw-output-section-bg);
#     border: var(--aw-output-section-border);
#     border-radius: 16px;
#     box-shadow: 0 0 8px rgba(0, 0, 0, 0.3), inset 0 0 10px rgba(0, 0, 0, 0.3);
#     align-items: stretch !important;
#     transition: all 0.15s;
# }
# .section-title {
#     width: 100%;
#     margin-bottom: 5px;
# }
# /* good use of space */
# .output-section ._horizontal {
#     display: grid;
#     grid-template-columns: repeat(3, 1fr);
# }
#
#
# /* Animation of Elements */
#
# .mainResult-container,
# .output-section {
#     animation: showedResult 1s cubic-bezier(0.785, 0.135, 0.15, 0.86);
# }
# .output-item {
#     animation: showedText 1s cubic-bezier(0.785, 0.135, 0.15, 0.86);
# }
#
# @keyframes showedResult {
#     0% {
#         transform: translate3d(0, 15%, 0);
#         opacity: 0;
#     }
#     100% {
#         transform: translate3d(0, 0, 0);
#         opacity: 1;
#     }
# }
#
# @keyframes showedText {
#     0% {
#         transform: translate3d(-30%, 0, 0);
#         opacity: 0;
#     }
#     100% {
#         transform: translate3d(0, 0, 0);
#         opacity: 1;
#     }
# }</style>
# VBox(children=(HTML(value='<div><span class="header-main-title">DOWNLOAD RESULTS</span><span style="color: gre…

# %% [markdown]
# ## 3. Start 🔽

# %%
# Launch WebUI.
# %run $scripts_dir/launch.py
# Out:
# >> Total Tunnels: 4 | Success: 4 | Errors: 0
#
# 🔧 WebUI: A1111
# Python 3.10.18 (main, Jul  8 2025, 21:00:10) [Clang 20.1.4 ]
# Version: v1.10.1
# Commit hash: 82a973c04367123ae98bd9abdf80d9eda9b910e2
# Installing requirements
# loading WD14-tagger reqs from /root/A1111/extensions/wd14-tagger/requirements.txt
# Checking WD14-tagger requirements.
# Launching Web UI with arguments: --xformers --no-half-vae --share --enable-insecure-extension-access --disable-console-progressbars --theme dark --anxety blue
# 2025-08-28 21:03:51.074917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756415031.374091    5963 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756415031.456873    5963 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1756415032.054719    5963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756415032.054758    5963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756415032.054773    5963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1756415032.054777    5963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-28 21:03:52.107815: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [CivitAI-Browser+] - Aria2 RPC started
# ControlNet preprocessor location: /root/A1111/extensions/ControlNet/annotator/downloads
# 2025-08-28 21:04:00,303 - ControlNet - INFO - ControlNet v1.1.455
# Forge: False, reForge: False
# [ForgeCouple] - INFO - Loaded Adv. Presets...
# ▶ SD-Hub: v11
# Tag Autocomplete: Could not locate model-keyword extension, Lora trigger word completion will be limited to those added through the extra networks menu.
# [-] ADetailer initialized. version: 25.3.0, num models: 10
# == WD14 tagger /gpu:0, uname_result(system='Linux', node='54b9ec03650b', release='6.1.123+', version='#1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025', machine='x86_64') ==
# Loading weights [bdb59bac77] from /root/A1111/models/Stable-diffusion/WAI-illustrious_V14.safetensors
# [Anxety-Theme] - Using command line accent color: blue
# Creating model from config: /root/A1111/repositories/generative-models/configs/inference/sd_xl_base.yaml
# Applying attention optimization: xformers... done.
# Model loaded in 36.3s (load weights from disk: 3.9s, create model: 1.0s, apply weights to model: 29.9s, apply half(): 0.2s, load textual inversion embeddings: 0.2s, calculate empty prompt: 0.9s).
# 2025-08-28 21:04:40,715 - ControlNet - INFO - ControlNet UI callback registered.
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://5145488ede3cd7bc73.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# [CivitAI-Extension] - INFO - Starting CivitAI-Extension V2.1
# IIB Database file has been successfully backed up to the backup folder.
# GenParamsGetter detected!
# GenParamsGetter detected!
# Startup time: 100.2s (prepare environment: 35.5s, import torch: 7.4s, import gradio: 1.6s, setup paths: 9.5s, initialize shared: 0.3s, other imports: 0.3s, load scripts: 5.3s, initialize extra networks: 0.1s, create ui: 38.4s, gradio launch: 1.5s, app_started_callback: 0.1s).
#
# +==================================================================================================+
#
#  🔗 Tunnel Localtunnel  URL: http://neat-tools-mate.loca.lt | Password: 34.124.230.44
#  🔗 Tunnel Gradio       URL: http://92836cb2d8af2adffe.gradio.live
#  🔗 Tunnel Pinggy       URL: http://gexvn-34-124-230-44.a.free.pinggy.link
#  🔗 Tunnel Cloudflared  URL: http://signals-holdings-cartoon-tunnel.trycloudflare.com
#
# +==================================================================================================+
#
# Loading VAE weights specified in settings: /root/A1111/models/VAE/sdxl.vae.safetensors
# Applying attention optimization: xformers... done.
# VAE weights loaded.
# Loading WD14 moat tagger v2 model file from SmilingWolf/wd-v1-4-moat-tagger-v2, model.onnx
# Loaded WD14 moat tagger v2 model from SmilingWolf/wd-v1-4-moat-tagger-v2
# Calculating sha256 for /root/A1111/models/VAE/sdxl.vae.safetensors: 63aeecb90ff7bc1c115395962d3e803571385b61938377bc7089b36e81e92e2e
# 2025-08-28 21:07:37,544 - ControlNet - INFO - unit_separate = False, style_align = False
# *** Error running process: /root/A1111/extensions/ControlNet/scripts/controlnet.py
#     Traceback (most recent call last):
#       File "/root/A1111/modules/scripts.py", line 832, in process
#         script.process(p, *script_args)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 1228, in process
#         self.controlnet_hack(p)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 1213, in controlnet_hack
#         self.controlnet_main_entry(p)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 919, in controlnet_main_entry
#         model_net, control_model_type = Script.load_control_model(p, unet, unit.model)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 436, in load_control_model
#         control_model = Script.build_control_model(p, unet, model)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 446, in build_control_model
#         raise RuntimeError("You have not selected any ControlNet Model.")
#     RuntimeError: You have not selected any ControlNet Model.
#
# ---
# UmiAI: No tags found in wildcard file "lora" or file does not exist
# {}
#  12% 3/24 [00:02<00:16,  1.27it/s]Downloading TAESD model to: /root/A1111/models/VAE-taesd/taesdxl_decoder.pth
#  21% 5/24 [00:04<00:15,  1.24it/s]
# 100% 4.69M/4.69M [00:00<00:00, 162MB/s]
# 100% 24/24 [00:20<00:00,  1.16it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# 0: 640x448 2 faces, 36.3ms
# Speed: 7.9ms preprocess, 36.3ms inference, 109.1ms postprocess per image at shape (1, 3, 640, 448)
# {}
# 100% 15/15 [00:13<00:00,  1.08it/s]
# [-] ADetailer: applied 1st ad_negative_prompt: '(((pointy_nose:1.9))),
# (((brown_eyelashes:1.9))), (((pink_eyes:1.9))), (((blue_eyes:1.9))),
# (((green_eyes:1.9))), (((pink_eyes:1.9))), (((yellow_eyes:1.9))),, lowres,
# (worst quality, low quality:1.2), bad anatomy, bad hands, 4koma, comic,
# greyscale, censored, jpeg artifacts, overly saturated, overly vivid'
# {}
# 100% 15/15 [00:13<00:00,  1.09it/s]
# [-] ADetailer: applied 1st ad_negative_prompt: '(((pointy_nose:1.9))),
# (((brown_eyelashes:1.9))), (((pink_eyes:1.9))), (((blue_eyes:1.9))),
# (((green_eyes:1.9))), (((pink_eyes:1.9))), (((yellow_eyes:1.9))),, lowres,
# (worst quality, low quality:1.2), bad anatomy, bad hands, 4koma, comic,
# greyscale, censored, jpeg artifacts, overly saturated, overly vivid'
#
# 0: 640x448 3 hands, 19.9ms
# Speed: 3.5ms preprocess, 19.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 448)
# {}
# 100% 14/14 [00:12<00:00,  1.12it/s]
# {}
# 100% 14/14 [00:12<00:00,  1.14it/s]
# {}
# 100% 14/14 [00:12<00:00,  1.14it/s]
# 2025-08-28 21:09:28,234 - ControlNet - INFO - unit_separate = False, style_align = False
# *** Error running process: /root/A1111/extensions/ControlNet/scripts/controlnet.py
#     Traceback (most recent call last):
#       File "/root/A1111/modules/scripts.py", line 832, in process
#         script.process(p, *script_args)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 1228, in process
#         self.controlnet_hack(p)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 1213, in controlnet_hack
#         self.controlnet_main_entry(p)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 919, in controlnet_main_entry
#         model_net, control_model_type = Script.load_control_model(p, unet, unit.model)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 436, in load_control_model
#         control_model = Script.build_control_model(p, unet, model)
#       File "/root/A1111/extensions/ControlNet/scripts/controlnet.py", line 446, in build_control_model
#         raise RuntimeError("You have not selected any ControlNet Model.")
#     RuntimeError: You have not selected any ControlNet Model.
#
# ---
# UmiAI: No tags found in wildcard file "lora" or file does not exist
# {}
# [CivitAI-Browser+] - Model saved to: /root/A1111/models/Lora/OMDV1.safetensors
# [CivitAI-Browser+] - Model info saved to: /root/A1111/models/Lora/OMDV1.json
# [CivitAI-Browser+] - Preview saved at: /root/A1111/models/Lora/OMDV1.preview.png

# %% [markdown]
# ---
# # Utilities

# %%
# Run AutoCleaner.
# %run $scripts_dir/auto-cleaner.py
